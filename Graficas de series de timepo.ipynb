# %% [markdown]
# # Underwater temperature

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_uw["Date"] = pd.to_datetime(df_underwater["Date"])

# %%
df_uw = pd.read_csv("underwater_temperature.csv", encoding = 'unicode_escape')
df_uw = df_uw[['ID', 'Site', 'Latitude', 'Longitude', 'Date', 'Time', 'Depth', 'Temp (°C)']]
df_uw
# Out:
#             ID           Site  Latitude  Longitude        Date      Time  \
# 0            1   Ilha Deserta   27.2706    48.3310  2013/02/20  11:40:02
# 1            2   Ilha Deserta   27.2706    48.3310  2013/02/20  12:00:03
# 2            3   Ilha Deserta   27.2706    48.3310  2013/02/20  12:20:04
# 3            4   Ilha Deserta   27.2706    48.3310  2013/02/20  12:40:05
# 4            5   Ilha Deserta   27.2706    48.3310  2013/02/20  13:00:06
# ...        ...            ...       ...        ...         ...       ...
# 408633  408634  lha do Xavier   27.6092    48.3858  2013/03/07  09:03:29
# 408634  408635  lha do Xavier   27.6092    48.3858  2013/03/07  09:23:29
# 408635  408636  lha do Xavier   27.6092    48.3858  2013/03/07  09:43:29
# 408636  408637  lha do Xavier   27.6092    48.3858  2013/03/07  10:03:29
# 408637  408638  lha do Xavier   27.6092    48.3858  2013/03/07  10:23:29
#
#         Depth  Temp (°C)
# 0        12.0     24.448
# 1        12.0     24.448
# ...

# %%
x = df_uw["Date"]
y = df_uw["Temp (°C)"]

# %%
plt.plot(x, y)
plt.ylabel("Temp (°C)")
plt.xlabel("Date")
plt.title("Underwater temperature")
# Out:
# Text(0.5, 1.0, 'Underwater temperature')

# %% [markdown]
# # Netflix Stock Price

# %%
df_N = pd.read_csv('NFLX.csv')
df_N
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#          Volume
# 0     104790000
# ...

# %%
del df_N["Date"]
df_N.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df_N.index = pd.to_datetime(df_N["Date"])

# %%
del df_N["Volume"]

# %%
sns.lineplot(df_N["Close"])
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %% [markdown]
# Las acciones tuvieron una tendencia positiva, pero en 2021 paso algo que hizo que bajara de manera brusca

# %%
from pandas.plotting import lag_plot
lag_plot(df_N, lag=1)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df_N, lag=12)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 12)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# %%
plot_acf(df_N["Close"], lags=40)
